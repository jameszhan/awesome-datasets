# %%
X = [19,  21,  22,  25,  59,  158, 250, 278, 280, 281,
     283, 290, 295, 302, 310, 319, 330, 342, 355, 370,
     386, 486, 511, 536]
Y = [1,   1,   1,   1,   4,   11,  17,  19,  19,  19,
     19,  20,  20,  21,  21,  22,  23,  23,  24,  25,
     27,  34,  35,  37]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array(X)
plt.rcParams['figure.figsize'] = (12.0, 8.0)
plt.plot(x, Y, 'o', label='Data', markersize=3)
plt.show()
