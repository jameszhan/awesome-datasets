# %%
import pandas as pd

# %%
df = pd.read_excel('https://dl.zizhizhan.com/datasets/team.xlsx')

# %%
df
# Out:
#         name team  Q1  Q2  Q3  Q4
# 0      Liver    E  89  21  24  64
# 1       Arry    C  36  37  37  57
# 2        Ack    A  57  60  18  84
# 3      Eorge    C  93  96  71  78
# 4        Oah    D  65  49  61  86
# ..       ...  ...  ..  ..  ..  ..
# 95   Gabriel    C  48  59  87  74
# 96   Austin7    C  21  31  30  43
# 97  Lincoln4    C  98  93   1  20
# 98       Eli    E  11  74  58  91
# 99       Ben    E  21  43  41  74
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#     name team  Q1  Q2  Q3  Q4
# 0  Liver    E  89  21  24  64
# 1   Arry    C  36  37  37  57
# 2    Ack    A  57  60  18  84
# 3  Eorge    C  93  96  71  78
# 4    Oah    D  65  49  61  86

# %%
df.tail()
# Out:
#         name team  Q1  Q2  Q3  Q4
# 95   Gabriel    C  48  59  87  74
# 96   Austin7    C  21  31  30  43
# 97  Lincoln4    C  98  93   1  20
# 98       Eli    E  11  74  58  91
# 99       Ben    E  21  43  41  74

# %%
df.sample(5) # 随机查看5条
# Out:
#         name team  Q1  Q2  Q3  Q4
# 29     Riley    E  35  26  59  83
# 16    Joshua    A  63   4  80  30
# 25  Harrison    B  89  13  18  75
# 43      Jude    E   8  45  13  65
# 56     David    B  21  47  99   2

# %%
df.shape
# Out:
# (100, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    100 non-null    object
#  1   team    100 non-null    object
#  2   Q1      100 non-null    int64
#  3   Q2      100 non-null    int64
#  4   Q3      100 non-null    int64
#  5   Q4      100 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#                Q1          Q2          Q3          Q4
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.200000   52.550000   52.670000   52.780000
# std     29.962603   29.845181   26.543677   27.818524
# min      1.000000    1.000000    1.000000    2.000000
# 25%     19.500000   26.750000   29.500000   29.500000
# 50%     51.500000   49.500000   55.000000   53.000000
# 75%     74.250000   77.750000   76.250000   75.250000
# max     98.000000   99.000000   99.000000   99.000000

# %%
df.dtypes
# Out:
# name    object
# team    object
# Q1       int64
# Q2       int64
# Q3       int64
# Q4       int64
# dtype: object

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['name', 'team', 'Q1', 'Q2', 'Q3', 'Q4'], dtype='object')]

# %%
df.columns
# Out:
# Index(['name', 'team', 'Q1', 'Q2', 'Q3', 'Q4'], dtype='object')

# %%
df.set_index('name', inplace=True)

# %%
df
# Out:
#          team  Q1  Q2  Q3  Q4
# name
# Liver       E  89  21  24  64
# Arry        C  36  37  37  57
# Ack         A  57  60  18  84
# Eorge       C  93  96  71  78
# Oah         D  65  49  61  86
# ...       ...  ..  ..  ..  ..
# Gabriel     C  48  59  87  74
# Austin7     C  21  31  30  43
# Lincoln4    C  98  93   1  20
# Eli         E  11  74  58  91
# Ben         E  21  43  41  74
#
# [100 rows x 5 columns]

# %%
df.head()
# Out:
#       team  Q1  Q2  Q3  Q4
# name
# Liver    E  89  21  24  64
# Arry     C  36  37  37  57
# Ack      A  57  60  18  84
# Eorge    C  93  96  71  78
# Oah      D  65  49  61  86

# %%
df['Q1']
# Out:
# name
# Liver       89
# Arry        36
# Ack         57
# Eorge       93
# Oah         65
#             ..
# Gabriel     48
# Austin7     21
# Lincoln4    98
# Eli         11
# Ben         21
# Name: Q1, Length: 100, dtype: int64

# %%
df[['team', 'Q1']]
# Out:
#          team  Q1
# name
# Liver       E  89
# Arry        C  36
# Ack         A  57
# Eorge       C  93
# Oah         D  65
# ...       ...  ..
# Gabriel     C  48
# Austin7     C  21
# Lincoln4    C  98
# Eli         E  11
# Ben         E  21
#
# [100 rows x 2 columns]

# %%
df[df.index=='Liver']
# Out:
#       team  Q1  Q2  Q3  Q4
# name
# Liver    E  89  21  24  64

# %%
df[0:3]
# Out:
#       team  Q1  Q2  Q3  Q4
# name
# Liver    E  89  21  24  64
# Arry     C  36  37  37  57
# Ack      A  57  60  18  84

# %%
df[df.Q1 > 90]
# Out:
#           team  Q1  Q2  Q3  Q4
# name
# Eorge        C  93  96  71  78
# Henry        A  91  15  75  17
# Max          E  97  75  41   3
# Alexander    C  91  76  26  79
# Elijah       B  97  89  15  46
# Ryan         E  92  70  64  31
# Aaron        A  96  75  55   8
# Lincoln4     C  98  93   1  20

# %%
df.sort_values(by='Q1')
# Out:
#           team  Q1  Q2  Q3  Q4
# name
# Sebastian    C   1  14  68  48
# Harley       B   2  99  12  13
# Liam         B   2  80  24  25
# Lewis        B   4  34  77  28
# Finn         E   4   1  55  32
# ...        ...  ..  ..  ..  ..
# Eorge        C  93  96  71  78
# Aaron        A  96  75  55   8
# Elijah       B  97  89  15  46
# Max          E  97  75  41   3
# Lincoln4     C  98  93   1  20
#
# [100 rows x 5 columns]

# %%
df.sort_values(by='Q1', ascending=False)
# Out:
#           team  Q1  Q2  Q3  Q4
# name
# Lincoln4     C  98  93   1  20
# Max          E  97  75  41   3
# Elijah       B  97  89  15  46
# Aaron        A  96  75  55   8
# Eorge        C  93  96  71  78
# ...        ...  ..  ..  ..  ..
# Lewis        B   4  34  77  28
# Finn         E   4   1  55  32
# Liam         B   2  80  24  25
# Harley       B   2  99  12  13
# Sebastian    C   1  14  68  48
#
# [100 rows x 5 columns]

# %%
df.sort_values(['team', 'Q1'], ascending=[True, False])
# Out:
#          team  Q1  Q2  Q3  Q4
# name
# Aaron       A  96  75  55   8
# Henry       A  91  15  75  17
# Nathan      A  87  77  62  13
# Dylan       A  86  87  65  20
# Blake       A  78  23  93   9
# ...       ...  ..  ..  ..  ..
# Eli         E  11  74  58  91
# Jude        E   8  45  13  65
# Rory9       E   8  12  58  27
# Jackson5    E   6  10  15  33
# Finn        E   4   1  55  32
#
# [100 rows x 5 columns]

# %%
mydf = df.loc[:, 'Q1':'Q4']

mydf.where(mydf>=60, '不及格')
# Out:
#            Q1   Q2   Q3   Q4
# name
# Liver      89  不及格  不及格   64
# Arry      不及格  不及格  不及格  不及格
# Ack       不及格   60  不及格   84
# Eorge      93   96   71   78
# Oah        65  不及格   61   86
# ...       ...  ...  ...  ...
# Gabriel   不及格  不及格   87   74
# Austin7   不及格  不及格  不及格  不及格
# Lincoln4   98   93  不及格  不及格
# Eli       不及格   74  不及格   91
# Ben       不及格  不及格  不及格   74
#
# [100 rows x 4 columns]

# %%
df.groupby('team').sum()
# Out:
#         Q1    Q2    Q3    Q4
# team
# A     1066   639   875   783
# B      975  1218  1202  1136
# C     1056  1194  1068  1127
# D      860  1191  1241  1199
# E      963  1013   881  1033

# %%
df.groupby('team').mean()
# Out:
#              Q1         Q2         Q3         Q4
# team
# A     62.705882  37.588235  51.470588  46.058824
# B     44.318182  55.363636  54.636364  51.636364
# C     48.000000  54.272727  48.545455  51.227273
# D     45.263158  62.684211  65.315789  63.105263
# E     48.150000  50.650000  44.050000  51.650000

# %%
df.groupby('team').agg({
    'Q1': sum,
    'Q2': 'count',
    'Q3': 'mean',
    'Q4': max
})
# Out:
#         Q1  Q2         Q3  Q4
# team
# A     1066  17  51.470588  97
# B      975  22  54.636364  99
# C     1056  22  48.545455  98
# D      860  19  65.315789  99
# E      963  20  44.050000  98

# %%
df.groupby('team').sum().T
# Out:
# team     A     B     C     D     E
# Q1    1066   975  1056   860   963
# Q2     639  1218  1194  1191  1013
# Q3     875  1202  1068  1241   881
# Q4     783  1136  1127  1199  1033

# %%
df.groupby('team').sum().stack()
# Out:
# team
# A     Q1    1066
#       Q2     639
#       Q3     875
#       Q4     783
# B     Q1     975
#       Q2    1218
#       Q3    1202
#       Q4    1136
# C     Q1    1056
#       Q2    1194
#       Q3    1068
#       Q4    1127
# D     Q1     860
#       Q2    1191
#       Q3    1241
#       Q4    1199
# E     Q1     963
#       Q2    1013
#       Q3     881
#       Q4    1033
# dtype: int64

# %%
df.groupby('team').sum().unstack()
# Out:
#     team
# Q1  A       1066
#     B        975
#     C       1056
#     D        860
#     E        963
# Q2  A        639
#     B       1218
#     C       1194
#     D       1191
#     E       1013
# Q3  A        875
#     B       1202
#     C       1068
#     D       1241
#     E        881
# Q4  A        783
#     B       1136
#     C       1127
#     D       1199
#     E       1033
# dtype: int64

# %%
df.loc[:, 'Q1':'Q4'].mean()
# Out:
# Q1    49.20
# Q2    52.55
# Q3    52.67
# Q4    52.78
# dtype: float64

# %%
df.loc[:, 'Q1':'Q4'].mean(axis=1)
# Out:
# name
# Liver       49.50
# Arry        41.75
# Ack         54.75
# Eorge       84.50
# Oah         65.25
#             ...
# Gabriel     67.00
# Austin7     31.25
# Lincoln4    53.00
# Eli         58.50
# Ben         44.75
# Length: 100, dtype: float64

# %%
df.loc[:, 'Q1':'Q4'].corr()
# Out:
#           Q1        Q2        Q3        Q4
# Q1  1.000000  0.142088 -0.125436 -0.010781
# Q2  0.142088  1.000000  0.056270 -0.033213
# Q3 -0.125436  0.056270  1.000000  0.041418
# Q4 -0.010781 -0.033213  0.041418  1.000000

# %%
df.loc[:, 'Q1':'Q4'].count()
# Out:
# Q1    100
# Q2    100
# Q3    100
# Q4    100
# dtype: int64

# %%
df.loc[:, 'Q1':'Q4'].max()
# Out:
# Q1    98
# Q2    99
# Q3    99
# Q4    99
# dtype: int64

# %%
df.loc[:, 'Q1':'Q4'].min()
# Out:
# Q1    1
# Q2    1
# Q3    1
# Q4    2
# dtype: int64

# %%
df.loc[:, 'Q1':'Q4'].median()
# Out:
# Q1    51.5
# Q2    49.5
# Q3    55.0
# Q4    53.0
# dtype: float64

# %%
df.loc[:, 'Q1':'Q4'].std()
# Out:
# Q1    29.962603
# Q2    29.845181
# Q3    26.543677
# Q4    27.818524
# dtype: float64

# %%
df.loc[:, 'Q1':'Q4'].var()
# Out:
# Q1    897.757576
# Q2    890.734848
# Q3    704.566768
# Q4    773.870303
# dtype: float64

# %%
df.loc[:, 'Q1':'Q4'].mode(axis=1)
# Out:
#              0     1     2     3
# name
# Liver     21.0  24.0  64.0  89.0
# Arry      37.0   NaN   NaN   NaN
# Ack       18.0  57.0  60.0  84.0
# Eorge     71.0  78.0  93.0  96.0
# Oah       49.0  61.0  65.0  86.0
# ...        ...   ...   ...   ...
# Gabriel   48.0  59.0  74.0  87.0
# Austin7   21.0  30.0  31.0  43.0
# Lincoln4   1.0  20.0  93.0  98.0
# Eli       11.0  58.0  74.0  91.0
# Ben       21.0  41.0  43.0  74.0
#
# [100 rows x 4 columns]

# %%
# %matplotlib inline

# %%
df['Q1'].plot()
# Out:
# <AxesSubplot:xlabel='name'>

# %%
df.loc['Ben', 'Q1':'Q4'].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc['Ben', 'Q1':'Q4'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.loc['Ben', 'Q1':'Q4'].plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.groupby('team').sum().T.plot()
# Out:
# <AxesSubplot:>

# %%
df.groupby('team').count().Q1.plot.pie()
# Out:
# <AxesSubplot:ylabel='Q1'>
